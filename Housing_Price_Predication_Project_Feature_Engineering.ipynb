# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import chardet#for encoding
import warnings# to avoid the warnings
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_columns',0)

# %%
data=pd.read_csv("After_EDA.csv",index_col=0)
data.head()
# Out:
#           Lng        Lat  tradeTime  ...  floor_type_未知  floor_type_顶  floor_type_高
# 0  116.475489  40.019520       2016  ...          False         False          True
# 1  116.453917  39.881534       2016  ...          False         False          True
# 2  116.561978  39.877145       2016  ...          False         False         False
# 3  116.438010  40.076114       2016  ...          False         False         False
# 4  116.428392  39.886229       2016  ...          False         False         False
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Let's Findout the outlier in a dataset using Inter quartile Range(IQR)

# %%
data['totalPrice'].describe()
# Out:
# count    297990.000000
# mean        349.178136
# std         224.530679
# min           0.100000
# 25%         205.000000
# 50%         295.000000
# 75%         427.000000
# max        4900.000000
# Name: totalPrice, dtype: float64

# %%
data.totalPrice.quantile([0.25,0.50,0.75])
# Out:
# 0.25    205.0
# 0.50    295.0
# 0.75    427.0
# Name: totalPrice, dtype: float64

# %% [markdown]
# so,we got
#
# Q1=205 and
# Q3=427
#
# so,let's findout IQR

# %%
Q1=205
Q3=427
IQR=Q3-Q1
print("So,IQR of our totalPrice Features is",IQR)
# Out:
# So,IQR of our totalPrice Features is 222

# %%
#Let's Calculate the High and Low Value in a totalPrice Features
High=Q3+1.5*IQR
Low=Q1-1.5*IQR
print("High value of our totalPrice Features is",High)
print("Low value of our totalPrice Features is",Low)
# Out:
# High value of our totalPrice Features is 760.0
# Low value of our totalPrice Features is -128.0

# %%
df=data.copy()

# %%
#Let's remove the outlier
df=df[df['totalPrice']<=High]
df=df[df['totalPrice']>=Low]

# %%
print(data.shape)
print(df.shape)
# Out:
# (297990, 45)
# (283901, 45)

# %%
print("Total outlier Removed =",data.shape[0]-df.shape[0])
# Out:
# Total outlier Removed = 14121

# %% [markdown]
# #### Let's Findout important features for out model

# %%
df.columns
# Out:
# Index(['Lng', 'Lat', 'tradeTime', 'followers', 'totalPrice', 'square',
#        'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'constructionTime',
#        'ladderRatio', 'fiveYearsProperty', 'subway', 'communityAverage',
#        'floor_height', 'renovationCondition_2', 'renovationCondition_3',
#        'renovationCondition_4', 'buildingStructure_2', 'buildingStructure_3',
#        'buildingStructure_4', 'buildingStructure_5', 'buildingStructure_6',
#        'buildingType_2.0', 'buildingType_3.0', 'buildingType_4.0',
#        'district_2', 'district_3', 'district_4', 'district_5', 'district_6',
#        'district_7', 'district_8', 'district_9', 'district_10', 'district_11',
#        'district_12', 'district_13', 'elevator_1.0', 'floor_type_低',
#        'floor_type_底', 'floor_type_未知', 'floor_type_顶', 'floor_type_高'],
#       dtype='object')

# %%
X=df.drop(['totalPrice'],axis=1)
y=df['totalPrice']

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-macosx_12_0_arm64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 10.0 MB/s eta 0:00:0000:010:01m
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/bhawnagarg/Library/Python/3.8/lib/python/site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.5.0
#   Downloading scipy-1.10.1-cp38-cp38-macosx_12_0_arm64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 20.3 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 13.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.2.0
#
# [notice] A new release of pip available: 22.3 -> 23.3.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# so,for now let's notedown top 20 features for model
#
# 1> tradeTime
#
# 2> CommunityAverage
#
# 3> square
#
# 4> livingRoom
#
# 5> bathRoom
#
# 6> drawingRoom
#
# 7> renovationCondition
#
# 8> buildingStructure
#
# 9> elevator
#
# 10> constructionTime
#
# 11> Followers

# %% [markdown]
# ### Data Normalization
# Normalization (min-max Normalization)
#
# In this approach we scale down the feature in  between 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling=MinMaxScaler()

# %%
col_for_normalization=['Lng', 'Lat','followers','square','livingRoom', 'drawingRoom',
                       'kitchen', 'bathRoom','ladderRatio', 'fiveYearsProperty', 
                       'subway', 'communityAverage','floor_height']

# %%
df[col_for_normalization]=scaling.fit_transform(df[col_for_normalization])

# %%
df.head()
# Out:
#         Lng       Lat  tradeTime  ...  floor_type_未知  floor_type_顶  floor_type_高
# 0  0.630809  0.627253       2016  ...          False         False          True
# 1  0.597040  0.406733       2016  ...          False         False          True
# 3  0.572140  0.717698       2016  ...          False         False         False
# 4  0.557084  0.414236       2016  ...          False         False         False
# 5  0.616393  0.582255       2016  ...          False         False         False
#
# [5 rows x 45 columns]

# %%
df.to_csv("Data_For_Model.csv")
